# %%
import sys
sys.path.insert(0, '..')

from src.ingest.rama import load_wide, to_long, segment, interpolate

long = to_long(load_wide('../data/raw/2025O3.xls'), 'O3')
cca = long[long.station == 'CCA']

seg = segment(cca)
print(f"Filas: {len(cca)} -> {len(seg)}  (descartadas: {len(cca)-len(seg)})")
print(f"Segmentos: {seg.segment_id.nunique()}")

interp = interpolate(seg)
print(f"Interpoladas: {interp.interpolated.sum()}")
print(f"NaN restantes: {interp.value.isna().sum()}")
# Out:
# Filas: 8760 -> 8692  (descartadas: 68)
# Segmentos: 6
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 13
#       9 seg = segment(cca)
#      10 print(f"Filas: {len(cca)} -> {len(seg)}  (descartadas: {len(cca)-len(seg)})")
#      11 print(f"Segmentos: {seg.segment_id.nunique()}")
#      12
# ---> 13 interp = interpolate(seg)
#      14 print(f"Interpoladas: {interp.interpolated.sum()}")
#      15 print(f"NaN restantes: {interp.value.isna().sum()}")
#
# File ~/MaestriaPCIC/Tesis/lorawan11-rama-detection/notebooks/../src/ingest/rama.py:112, in interpolate(long)
#     109 long = long.copy()
#     110 long["interpolated"] = long["value"].isna()
#     111 long["value"] = (
# --> 112     long.groupby(["station", "segment_id"])["value"]
#     113     .transform(lambda s: s.interpolate(method="linear", limit_direction="both"))
#     114 )
#     115 return long
#
# ...
